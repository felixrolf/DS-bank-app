# %%
import pandas as pd

# %%
df_1 = pd.read_csv('../data/bank/kaggle_financial_payment_1.csv')
df_2 = pd.read_csv('../data/bank/kaggle_financial_payment_2.csv')

# %%
df_1.head()
# Out:
#    step       customer  age gender zipcodeOri       merchant zipMerchant  \
# 0     0  'C1093826151'  '4'    'M'    '28007'   'M348934600'     '28007'
# 1     0   'C352968107'  '2'    'M'    '28007'   'M348934600'     '28007'
# 2     0  'C2054744914'  '4'    'F'    '28007'  'M1823072687'     '28007'
# 3     0  'C1760612790'  '3'    'M'    '28007'   'M348934600'     '28007'
# 4     0   'C757503768'  '5'    'M'    '28007'   'M348934600'     '28007'
#
#               category  amount  fraud
# 0  'es_transportation'    4.55      0
# 1  'es_transportation'   39.68      0
# 2  'es_transportation'   26.89      0
# 3  'es_transportation'   17.25      0
# 4  'es_transportation'   35.72      0

# %%
columns_to_drop = ["step", "customer", "zipMerchant", "zipcodeOri"]
df_1b = df_1.drop(columns=columns_to_drop)

# %%
df_1b['m_gender'] = 0
df_1b['f_gender'] = 0
df_1b['u_gender'] = 0
df_1b['e_gender'] = 0
df_1b.loc[df_1['gender']=="'M'", 'm_gender'] = 1
df_1b.loc[df_1['gender']=="'F'", 'f_gender'] = 1
df_1b.loc[df_1['gender']=="'U'", 'u_gender'] = 1
df_1b.loc[df_1['gender']=="'E'", 'e_gender'] = 1

# %%
columns_to_drop = ["gender"]
df_1c = df_1b.drop(columns=columns_to_drop)

# %%
df_1c['BuR'] = 0
df_1c['Con'] = 0
df_1c['Fas'] = 0
df_1c['Foo'] = 0
df_1c['Hea'] = 0
df_1c['Hom'] = 0
df_1c['Hot'] = 0
df_1c['Hyp'] = 0
df_1c['Oth'] = 0
df_1c['SuT'] = 0
df_1c['Tec'] = 0
df_1c['Tran'] = 0
df_1c['Trav'] = 0
df_1c['WuB'] = 0
df_1c.loc[df_1['category']=="'es_barsandrestaurants'", 'BuR'] = 1
df_1c.loc[df_1['category']=="'es_contents'", 'Con'] = 1
df_1c.loc[df_1['category']=="'es_fashion'", 'Fas'] = 1
df_1c.loc[df_1['category']=="'es_food'", 'Foo'] = 1
df_1c.loc[df_1['category']=="'es_health'", 'Hea'] = 1
df_1c.loc[df_1['category']=="'es_home'", 'Hom'] = 1
df_1c.loc[df_1['category']=="'es_hotelservices'", 'Hot'] = 1
df_1c.loc[df_1['category']=="'es_hyper'", 'Hyp'] = 1
df_1c.loc[df_1['category']=="'es_otherservices'", 'Oth'] = 1
df_1c.loc[df_1['category']=="'es_sportsandtoys'", 'SuT'] = 1
df_1c.loc[df_1['category']=="'es_tech'", 'Tec'] = 1
df_1c.loc[df_1['category']=="'es_transportation'", 'Tran'] = 1
df_1c.loc[df_1['category']=="'es_travel'", 'Trav'] = 1
df_1c.loc[df_1['category']=="'es_wellnessandbeauty'", 'WuB'] = 1

# %%
columns_to_drop = ["category"]
df_1d = df_1c.drop(columns=columns_to_drop)

# %%
df_1d['Age=0'] = 0
df_1d['Age=1'] = 0
df_1d['Age=2'] = 0
df_1d['Age=3'] = 0
df_1d['Age=4'] = 0
df_1d['Age=5'] = 0
df_1d['Age=6'] = 0
df_1d['Age=U'] = 0
df_1d.loc[df_1['age']=="'0'", 'Age=0'] = 1
df_1d.loc[df_1['age']=="'1'", 'Age=1'] = 1
df_1d.loc[df_1['age']=="'2'", 'Age=2'] = 1
df_1d.loc[df_1['age']=="'3'", 'Age=3'] = 1
df_1d.loc[df_1['age']=="'4'", 'Age=4'] = 1
df_1d.loc[df_1['age']=="'5'", 'Age=5'] = 1
df_1d.loc[df_1['age']=="'6'", 'Age=6'] = 1
df_1d.loc[df_1['age']=="'U'", 'Age=U'] = 1

# %%
columns_to_drop = ["age"]
df_1e = df_1d.drop(columns=columns_to_drop)

# %%
df_1e['h1'] = 0
df_1e['h2'] = 0
df_1e['h3'] = 0
df_1e['h4'] = 0
df_1e['h5'] = 0
df_1e['h6'] = 0
df_1e['h7'] = 0
df_1e['h8'] = 0
df_1e['h9'] = 0
df_1e['h10'] = 0
df_1e['h11'] = 0
df_1e['h12'] = 0
df_1e['h13'] = 0
df_1e['h14'] = 0
df_1e['h15'] = 0
df_1e['h16'] = 0
df_1e['h17'] = 0
df_1e['h18'] = 0
df_1e.loc[df_1['merchant']=="'M1198415165'", 'h1'] = 1
df_1e.loc[df_1['merchant']=="'M1294758098'", 'h2'] = 1
df_1e.loc[df_1['merchant']=="'M1353266412'", 'h3'] = 1
df_1e.loc[df_1['merchant']=="'M151143676'", 'h4'] = 1
df_1e.loc[df_1['merchant']=="'M1535107174'", 'h5'] = 1
df_1e.loc[df_1['merchant']=="'M17379832'", 'h6'] = 1
df_1e.loc[df_1['merchant']=="'M1741626453'", 'h7'] = 1
df_1e.loc[df_1['merchant']=="'M1873032707'", 'h8'] = 1
df_1e.loc[df_1['merchant']=="'M1888755466'", 'h9'] = 1
df_1e.loc[df_1['merchant']=="'M2011752106'", 'h10'] = 1
df_1e.loc[df_1['merchant']=="'M209847108'", 'h11'] = 1
df_1e.loc[df_1['merchant']=="'M2122776122'", 'h12'] = 1
df_1e.loc[df_1['merchant']=="'M3697346'", 'h13'] = 1
df_1e.loc[df_1['merchant']=="'M480139044'", 'h14'] = 1
df_1e.loc[df_1['merchant']=="'M547558035'", 'h15'] = 1
df_1e.loc[df_1['merchant']=="'M732195782'", 'h16'] = 1
df_1e.loc[df_1['merchant']=="'M855959430'", 'h17'] = 1
df_1e.loc[df_1['merchant']=="'M980657600'", 'h18'] = 1

# %%
columns_to_drop = ["merchant"]
df_1f = df_1e.drop(columns=columns_to_drop)

# %%
import pandas as pd
import numpy as np

corr = df_1f.corr()
corr.style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_e446a11a_2edc_11e9_acfa_f018984f2aa9row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e446a11a_2edc_11e9_acfa_f018984f2aa9row0_col1 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_e446a11a_2edc_11e9_acfa_f018984f2aa9row0_col2 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_e446a11a_2edc_11e9_acfa_f018984f2aa9row0_col3 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_e446a11a_2edc_11e9_acfa_f018984f2aa9row0_col4 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_e446a11a_2edc_11e9_acfa_f018984f2aa9row0_col5 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_e446a11a_2edc_11e9_acfa_f018984f2aa9row0_col6 {
#             background-color:  #dbdaeb;
#             color:  #000000;
# ...

# %%
corr.loc[corr['fraud'] > 0.2]
# Out:
#           amount     fraud  m_gender  f_gender  u_gender  e_gender       BuR  \
# amount  1.000000  0.489967 -0.012880  0.013018 -0.001686 -0.000505  0.005205
# fraud   0.489967  1.000000 -0.025172  0.025575 -0.003259 -0.002512  0.006397
# SuT     0.131394  0.363631 -0.010344  0.010644 -0.002423 -0.001817 -0.008568
# Trav    0.695336  0.250284 -0.005467  0.005665 -0.001031 -0.001560 -0.003644
# h14     0.143005  0.319556 -0.011089  0.011215 -0.002268  0.000025 -0.008018
# h16     0.656835  0.245676 -0.005119  0.005299 -0.000942 -0.001425 -0.003330
# h18     0.128502  0.409547 -0.010388  0.010633 -0.001608 -0.001739 -0.005685
#
#              Con       Fas       Foo  ...        h9       h10       h11  \
# amount  0.002307  0.026118 -0.001581  ...  0.034474  0.051959  0.017671
# fraud  -0.004274  0.005618 -0.023793  ...  0.085249  0.123789  0.011522
# SuT    -0.003178 -0.008622 -0.017691  ... -0.003226 -0.001668 -0.006614
# ...

# %%
columns_to_drop = ["u_gender", "e_gender", "BuR", "Con", "Fas", "Foo", "Hom", "Hot", "Hyp", "Oth", "Tec", "Tran", "WuB", "Age=0", "Age=1", "Age=2", "Age=3", "Age=4", "Age=5", "Age=6", "Age=U", "h1","h2","h3","h4","h5","h6","h7","h8","h9","h10","h11","h12","h13","h15","h17"]
corr_clean = corr.drop(columns=columns_to_drop)
corr_clean.loc[corr['fraud'] > 0.2]
# Out:
#           amount     fraud  m_gender  f_gender       Hea       SuT      Trav  \
# amount  1.000000  0.489967 -0.012880  0.013018  0.146501  0.131394  0.695336
# fraud   0.489967  1.000000 -0.025172  0.025575  0.142029  0.363631  0.250284
# SuT     0.131394  0.363631 -0.010344  0.010644 -0.013746  1.000000 -0.002882
# Trav    0.695336  0.250284 -0.005467  0.005665 -0.005847 -0.002882  1.000000
# h14     0.143005  0.319556 -0.011089  0.011215  0.461301 -0.006341 -0.002697
# h16     0.656835  0.245676 -0.005119  0.005299 -0.005343 -0.002633  0.913781
# h18     0.128502  0.409547 -0.010388  0.010633 -0.009122  0.663599 -0.001912
#
#              h14       h16       h18
# amount  0.143005  0.656835  0.128502
# fraud   0.319556  0.245676  0.409547
# SuT    -0.006341 -0.002633  0.663599
# Trav   -0.002697  0.913781 -0.001912
# h14     1.000000 -0.002465 -0.004208
# h16    -0.002465  1.000000 -0.001748
# h18    -0.004208 -0.001748  1.000000

# %%
corr.shape
# Out:
# (46, 46)

# %%
corr.loc[corr['fraud'] > 0.2].plot()

# %%
corr_clean.loc[corr_clean['fraud'] > 0.2].plot()

# %%
corr.plot(x='amount', y='fraud')

# %%
#corr.loc[(corr['fraud'] >= 0.2) & (corr['fraud'] <= -0.2)]

# %%
df.loc[(df['column_name'] >= A) & (df['column_name'] <= B)]

# %%
df_1f.plot(x='amount', y='h11')
